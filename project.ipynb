# %%
from openai import OpenAI
from dotenv import load_dotenv
from rich.pretty import Pretty
import os

load_dotenv()
openai_client = OpenAI(
    base_url=os.getenv("OPENAI_BASE_URL=", "https://api.openai.com/v1"),
    api_key=os.getenv("OPENAI_API_KEY")
)

# %%
prompt = "How do I say in Japanese that something is hard to do?"

response = openai_client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": prompt}
    ],
    max_tokens=150
)

print(response.choices[0].message.content)
# Out:
# You can say "難しい" (muzukashii) which means "difficult" or "hard to do" in Japanese.

# %%
prompt = "How do I describe in Japanese the characteristic of something?"

response = openai_client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": prompt}
    ],
    max_tokens=150
)

print(response.choices[0].message.content)
# Out:
# To describe the characteristic of something in Japanese, you can use the phrase "〜の特徴は〜です" (〜 no tokuchou wa ~ desu).
# For example:
# - 彼の特徴は背が高いです (kare no tokuchou wa se ga takai desu) - His characteristic is that he is tall.
# - その商品の特徴は耐久性が高いです (sono shouhin no tokuchou wa taikyusei ga takai desu) - The characteristic of that product is that it has high durability.

# %%
prompt = "How do I say in Japanese that I have a tendency to get sick?"

response = openai_client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": prompt}
    ],
    max_tokens=150
)

print(response.choices[0].message.content)
# Out:
# 私は病気になりやすい傾向があります。 (Watashi wa byouki ni nariyasui keikou ga arimasu.)
